# %% [markdown]
# # P04-03: Small-world networks
#
# *November 16 2022*
#
# In the final unit of this week we study properties of synthetic and empirical small-world networks and show how we can visualize path funelling using `pathpy`. You can use this unit as a basis for your solution of some tasks on exercise sheet 3.

# %%
import pathpy as pp
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from constants import ROOT_DIR

plt.style.use('default')
sns.set_style("whitegrid")
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>
# C:\Users\ingos\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Shortest Paths in random vs. small-world networks
#
# One implication of the small-world property is that

# %%
n_random = pp.generators.ER_np(n=50, p=0.15, loops=False)

style = {}
style['edge_directed'] = False
style['edge_color'] = 'gray'
style['node_color'] = 'CornflowerBlue'
style['node_label_size'] = 2
style['node_size'] = 20
style['edge_size'] = 1.0

layout_style = {}
layout_style['layout'] = 'Fruchterman-Reingold'
layout_style['height'] = 600
layout_style['width'] = 400
layout_style['force'] = 0.5

layout =  pp.layout(n_random, **layout_style)
n_random.plot(**style, layout=layout)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x602bdec1a0cf4cd79f67b0b875ca9c00"></div>
# <div id="x26d86334041643cebc092180b36aed57"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [348.5013598648434, 261.45388322288494], "label_size": 2, "id_as_label": true}, {"uid": "1", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [304.1438239709688, 320.32350802556573], "label_size": 2, "id_as_label": true}, {"uid": "2", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [333.43271659887534, 308.314723558829], "label_size": 2, "id_as_label": true}, {"uid": "3", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [447.1826904423626, 204.9081482057412], "label_size": 2, "id_as_label": true}, {"uid": "4", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [572.972930932271, 433.4460034605745], "label_size": 2, "id_as_label": true}, {"uid": "5", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [276.5137448191625, 243.8497984636757], "label_size": 2, "id_as_label": true}, {"uid": "6", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [414.1249761822021, 335.5712105896472], "label_size": 2, "id_as_label": true}, {"uid": "7", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [381.782522032807, 226.1242551057664], "label_size": 2, "id_as_label": true}, {"uid": "8", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [563.4536094482116, 315.01481928312563], "label_size": 2, "id_as_label": true}, {"uid": "9", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [454.8451731503287, 179.83253592364736], "label_size": 2, "id_as_label": true}, {"uid": "10", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [203.07182501157945, 307.48930097631893], "label_size": 2, "id_as_label": true}, {"uid": "11", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [364.099996971591, 497.4974570792302], "label_size": 2, "id_as_label": true}, {"uid": "12", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [460.3494055277321, 325.7310457277074], "label_size": 2, "id_as_label": true}, {"uid": "13", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [514.7750959910002, 19.531358542884277], "label_size": 2, "id_as_label": true}, {"uid": "14", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [541.6116757240261, 206.93047232940887], "label_size": 2, "id_as_label": true}, {"uid": "15", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [421.7349744646706, 399.0855109386795], "label_size": 2, "id_as_label": true}, {"uid": "16", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [437.279910

# %%
def funelling_plot(n, style={}, layout=None, source=None):
    # visualise number of shortest paths from given node x to all other nodes, passing through neighbors of x
    if source is None:
        source = np.random.choice(list(n.nodes.uids))
        print(source)
    labels = { v: v for v in n.nodes.uids }
    style['node_label_size'] = { v: 2 for v in n.nodes.uids}
    style['node_size'] = { v: 20 for v in n.nodes.uids}
    style['node_color'] = { v: 'CornflowerBlue' for v in n.nodes.uids }
    style['node_color'][source] = 'Red'

    tree = pp.algorithms.shortest_path_tree(n, source=source)
    assert pp.algorithms.check_tree(tree)

    # compute tree size for all neighbors of source
    for v in n.successors[source]:    
        s = pp.algorithms.tree_size(tree, v.uid)
        labels[v.uid] = v.uid + ': ' + str(s)
        style['node_label_size'][v.uid] = 2 + 0.1*s
        style['node_size'][v.uid] = 5 + 2*s
        style['node_color'][v.uid] = 'Green'
    if layout is None:
        layout = pp.layout(n, layout='fr', force=0.5)
    
    n.plot(node_label=labels, node_id_as_label=False, **style, layout=layout)

# %%
n_random = pp.generators.Watts_Strogatz(n=50, s=2, p=1, loops=False)
funelling_plot(n_random, style)
# Out:
# 39
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x5aec26b083914f50a22555469809524a"></div>
# <div id="xc5e652c12e0b4f72bdb51114b62d1a3f"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "0", "label": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [359.28282303559456, 522.5], "label_size": 2, "id_as_label": false}, {"uid": "1", "label": "1", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [392.98432546828644, 478.8165936733469], "label_size": 2, "id_as_label": false}, {"uid": "2", "label": "2", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [417.17535122978904, 29.75126909918788], "label_size": 2, "id_as_label": false}, {"uid": "3", "label": "3", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [354.4126004355335, 247.08871465293896], "label_size": 2, "id_as_label": false}, {"uid": "4", "label": "4", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [549.2583136419241, 242.05498172435557], "label_size": 2, "id_as_label": false}, {"uid": "5", "label": "5", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [533.3380019237122, 263.94891642061845], "label_size": 2, "id_as_label": false}, {"uid": "6", "label": "6: 21", "size": 47.0, "color": "Green", "opacity": 0.2, "coordinates": [379.3332140313957, 347.08242078623584], "label_size": 4.1, "id_as_label": false}, {"uid": "7", "label": "7", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [568.0933952866786, 199.02623224208202], "label_size": 2, "id_as_label": false}, {"uid": "8", "label": "8", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [354.792955640841, 377.93029896059073], "label_size": 2, "id_as_label": false}, {"uid": "9", "label": "9", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [542.0284177682533, 178.62086017905187], "label_size": 2, "id_as_label": false}, {"uid": "10", "label": "10", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [433.7726609229245, 428.76607377293226], "label_size": 2, "id_as_label": false}, {"uid": "11", "label": "11", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [419.40433884430206, 167.30739475887572], "label_size": 2, "id_as_label": false}, {"uid": "12", "label": "12", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [358.86483304408193, 60.072317953813695], "label_size": 2, "id_as_label": false}, {"uid": "13", "label": "13", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [460.0207020322848, 190.05225874778625], "label_size": 2, "id_as_label": false}, {"uid": "14", "label": "14", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [357.3182744364568, 148.9121005147448], "label_size": 2, "id_as_label": false}, {"uid": "15", "label": "15", "size":

# %%
n_ring = pp.generators.Watts_Strogatz(n=50, s=2, p=0)
layout = pp.layout(n_ring, layout='lattice', dimension=1)
funelling_plot(n_ring, style, layout)
# Out:
# 20
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x06f8f0cbe9ca4fa792f425bc2ec0e028"></div>
# <div id="x62adc064f1294334b5f67ba1a90eea9c"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "0", "label": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [400.0, 29.5], "label_size": 2, "id_as_label": false}, {"uid": "1", "label": "1", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [430.7693088400367, 31.435840827295692], "label_size": 2, "id_as_label": false}, {"uid": "2", "label": "2", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [461.0533672989718, 37.212833942921065], "label_size": 2, "id_as_label": false}, {"uid": "3", "label": "3", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [490.3745776840885, 46.739872714434284], "label_size": 2, "id_as_label": false}, {"uid": "4", "label": "4", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [518.2705269919711, 59.86671004923153], "label_size": 2, "id_as_label": false}, {"uid": "5", "label": "5", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [544.3012794378021, 76.38632788095038], "label_size": 2, "id_as_label": false}, {"uid": "6", "label": "6", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [568.0563145054931, 96.0382019680435], "label_size": 2, "id_as_label": false}, {"uid": "7", "label": "7", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [589.1610011014563, 118.51241051669672], "label_size": 2, "id_as_label": false}, {"uid": "8", "label": "8", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [607.2825057107448, 143.45452183265638], "label_size": 2, "id_as_label": false}, {"uid": "9", "label": "9", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [622.1350413804078, 170.4711839207747], "label_size": 2, "id_as_label": false}, {"uid": "10", "label": "10", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [633.4843747504602, 199.13632788095043], "label_size": 2, "id_as_label": false}, {"uid": "11", "label": "11", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [641.1515200538931, 228.99788726920463], "label_size": 2, "id_as_label": false}, {"uid": "12", "label": "12", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [645.0155618291407, 259.5849274555536], "label_size": 2, "id_as_label": false}, {"uid": "13", "label": "13", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [645.0155618291407, 290.41507254444645], "label_size": 2, "id_as_label": false}, {"uid": "14", "label": "14", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [641.151520053893, 321.0021127307955], "label_size": 2, "id_as_label": false}, {"uid": "15", "label": "15", "size": 20.0, "color": "Cor

# %%
n_ws = pp.generators.Watts_Strogatz(n=50, s=4, p=0.05)
funelling_plot(n_ws, style)
# Out:
# 11
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xaf8bb583a8d743f9a86d6ac9b3ed6c34"></div>
# <div id="x44d2291bf7e44f858f5c4f9a9b6362d2"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "0", "label": "0", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [191.962669113102, 426.68531791202327], "label_size": 2, "id_as_label": false}, {"uid": "1", "label": "1", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [265.02804046597987, 358.2195333159475], "label_size": 2, "id_as_label": false}, {"uid": "2", "label": "2", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [147.61650290990445, 340.43557959353654], "label_size": 2, "id_as_label": false}, {"uid": "3", "label": "3", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [134.36259862109742, 300.9361016744184], "label_size": 2, "id_as_label": false}, {"uid": "4", "label": "4", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [128.10259908797005, 254.94280865593942], "label_size": 2, "id_as_label": false}, {"uid": "5", "label": "5", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [153.29650741501257, 197.66149308240944], "label_size": 2, "id_as_label": false}, {"uid": "6", "label": "6", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [214.43086362724856, 188.8656221525215], "label_size": 2, "id_as_label": false}, {"uid": "7", "label": "7: 13", "size": 31.0, "color": "Green", "opacity": 0.2, "coordinates": [182.33826739125504, 165.8383051257444], "label_size": 3.3, "id_as_label": false}, {"uid": "8", "label": "8: 1", "size": 7.0, "color": "Green", "opacity": 0.2, "coordinates": [173.50341449053306, 210.87997275941876], "label_size": 2.1, "id_as_label": false}, {"uid": "9", "label": "9: 18", "size": 41.0, "color": "Green", "opacity": 0.2, "coordinates": [299.9527972703411, 178.06653373836673], "label_size": 3.8, "id_as_label": false}, {"uid": "10", "label": "10: 4", "size": 13.0, "color": "Green", "opacity": 0.2, "coordinates": [255.273691816515, 262.7176373754553], "label_size": 2.4, "id_as_label": false}, {"uid": "11", "label": "11", "size": 20.0, "color": "Red", "opacity": 0.2, "coordinates": [226.60403634858233, 284.75337106846297], "label_size": 2, "id_as_label": false}, {"uid": "12", "label": "12: 4", "size": 13.0, "color": "Green", "opacity": 0.2, "coordinates": [255.66779341187012, 295.5411081041807], "label_size": 2.4, "id_as_label": false}, {"uid": "13", "label": "13: 2", "size": 9.0, "color": "Green", "opacity": 0.2, "coordinates": [204.88960391796877, 413.0393079692273], "label_size": 2.2, "id_as_label": false}, {"uid": "14", "label": "14: 1", "size": 7.0, "color": "Green", "opacity": 0.2, "coordinates": [267.6524642995612, 378.28231441459184], "label_size": 2.1, "id_as_label": false}, {"uid": "15", "label": "15: 6", "size": 17.0, "color": "Gree

# %% [markdown]
# # Empirical small-world networks
#
# We finally test for which of the three empirical networks we find a small-world property. For this, we compare their average shortest path lengths and clustering coefficients to that of random networks with the same macrostate. If the average shortest path lengths are similar to that of a random network (or even smaller) and the clustering coefficient is much larger than expected at random, we call the network a small-world network.

# %%
n_gentoo = pp.io.sql.read_network(f'{ROOT_DIR}/data/networks.db', sql='SELECT DISTINCT source, target FROM gentoo', directed=False, loops=False).largest_connected_component()
n_highschool = pp.io.sql.read_network(f'{ROOT_DIR}/data/networks.db', sql='SELECT DISTINCT source, target FROM highschool', directed=False, loops=False).largest_connected_component()
n_lotr = pp.io.sql.read_network(f'{ROOT_DIR}/data/networks.db', sql='SELECT DISTINCT source, target FROM lotr', directed=False, loops=False).largest_connected_component()
# Out:
# [04-21 15:33:04: WARNING] 154 edges existed already and were not be considered. To capture those edges, please enable multiedges and/or directed!
# [04-21 15:33:04: WARNING] 67 edges existed already and were not be considered. To capture those edges, please enable multiedges and/or directed!

# %%
r_gentoo = pp.generators.ER_np_randomize(n_gentoo).largest_connected_component()

print('cc_e = ', pp.statistics.avg_clustering_coefficient(n_gentoo))
print('cc_r = ', pp.statistics.avg_clustering_coefficient(r_gentoo))
print('<l_e> = ', pp.algorithms.avg_path_length(n_gentoo))
print('<l_r> = ', pp.algorithms.avg_path_length(r_gentoo))
# Out:
# cc_e =  0.017357355654577633
# cc_r =  0.0
# <l_e> =  3.1096379146451367
# <l_r> =  6.542920898738073

# %%
r_highschool = pp.generators.ER_np_randomize(n_highschool).largest_connected_component()

print('cc_e = ', pp.statistics.avg_clustering_coefficient(n_highschool))
print('cc_r = ', pp.statistics.avg_clustering_coefficient(r_highschool))
print('<l_e> = ', pp.algorithms.avg_path_length(n_highschool))
print('<l_r> = ', pp.algorithms.avg_path_length(r_highschool))
# Out:
# cc_e =  0.446799543049543
# cc_r =  0.05288245834464322
# <l_e> =  5.362745098039215
# <l_r> =  2.853154821250534

# %%
r_lotr = pp.generators.ER_np_randomize(n_lotr).largest_connected_component()

print('cc_e = ', pp.statistics.avg_clustering_coefficient(n_lotr))
print('cc_r = ', pp.statistics.avg_clustering_coefficient(r_lotr))
print('<l_e> = ', pp.algorithms.avg_path_length(n_lotr))
print('<l_r> = ', pp.algorithms.avg_path_length(r_lotr))
# Out:
# cc_e =  0.5848854454659764
# cc_r =  0.07093375603033196
# <l_e> =  2.6724273369992146
# <l_r> =  2.433958029401863

# %%
funelling_plot(n_lotr, source='Sam')
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xd6ccfd8b7c81415191625e273c4321a4"></div>
# <div id="x63a7740074604a1d98a93c09982f60d9"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#    var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -20, "forceRepel": -300, "forceAlpha": 0.1, "restartAlpha": 1, "alphaMin": 0.001, "targetAlpha": 0, "chargeDistance": 800, "repelDistance": 200, "velocityDecay": 0.4, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "targetAlphaDragStarted": 0.3, "targetAlphaDragEnd": 0.0, "linkStrengthMin": 0.0, "linkStrengthMax": 0.45, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "Gamling", "label": "Gamling", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [271.7077211016695, 371.5717077672243], "label_size": 2, "id_as_label": false}, {"uid": "Grimbold", "label": "Grimbold", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [536.5257121268722, 277.6807152029878], "label_size": 2, "id_as_label": false}, {"uid": "F\u00ebanor", "label": "F\u00ebanor", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [310.1564391904444, 60.64288509328071], "label_size": 2, "id_as_label": false}, {"uid": "Beorn", "label": "Beorn", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [353.6413591352485, 436.2752645493187], "label_size": 2, "id_as_label": false}, {"uid": "H\u00farin", "label": "H\u00farin", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [402.9597991920746, 359.5778081439009], "label_size": 2, "id_as_label": false}, {"uid": "Imrahil", "label": "Imrahil", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [399.20178290285645, 266.07824820495955], "label_size": 2, "id_as_label": false}, {"uid": "Daeron", "label": "Daeron", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [341.4449184803615, 65.7487208562975], "label_size": 2, "id_as_label": false}, {"uid": "Lotho", "label": "Lotho", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [374.4419166927125, 162.5736538383802], "label_size": 2, "id_as_label": false}, {"uid": "Goldilocks", "label": "Goldilocks", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [449.3775647032692, 143.75581347979198], "label_size": 2, "id_as_label": false}, {"uid": "Gorbag", "label": "Gorbag: 1", "size": 7.0, "color": "Green", "opacity": 0.2, "coordinates": [179.45725885513195, 353.07561897438654], "label_size": 2.1, "id_as_label": false}, {"uid": "Gram", "label": "Gram", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [262.42143128751377, 450.93413791165534], "label_size": 2, "id_as_label": false}, {"uid": "Bergil", "label": "Bergil", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [270.7941955378106, 334.11465575623197], "label_size": 2, "id_as_label": false}, {"uid": "Thranduil", "label": "Thranduil", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [533.7371504696528, 174.92906470732487], "label_size": 2, "id_as_label": false}, {"uid": "Glorfindel", "label": "Glorfindel", "size": 20.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [442.05031894023506, 260.61506991025306], "label_size": 2, "id_as_label": false}, {"uid": "Gh\u00e2n-buri-Gh\u00e2n", "labe
